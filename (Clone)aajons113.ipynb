# %%
# %sql
"Restoring serverless notebook session state..."

# %%
dbutils.widgets.text("year_param", "2020")
year_value = dbutils.widgets.get("year_param")

# %%
print('x')

# %%
dbutils.widgets.text(
    "param_13",      # name
    "1234",   # defaultValue
    "P1"  # label (optional)
)

# %%
param_value = dbutils.widgets.get("param_2")
print(param_value)

# %%
# %pip uninstall -y simplejson

# %%
# !pip list

# %%
a=1

# %%
print(aqqqq)
